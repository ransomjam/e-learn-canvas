# %%
# Install dependencies
# !npm install

# %%
import subprocess
import time
import os

# Start server in background
server_process = subprocess.Popen(['node', 'index.js'], stdout=subprocess.PIPE, stderr=subprocess.PIPE)
print("Server started in background...")

# Give it time to start
time.sleep(3)

# Run test script
print("Running test-payment.js...")
test_result = subprocess.run(['node', 'test-payment.js'], capture_output=True, text=True)

print("--- TEST OUTPUT ---")
print(test_result.stdout)
print("--- TEST ERRORS ---")
print(test_result.stderr)

# Clean up
server_process.terminate()
print("Server stopped.")

# %%
print("Hello from notebook")

# %%
import os
import subprocess

print("Changing directory to server...")
os.chdir('c:\\Users\\user\\Desktop\\New folder (2)\\ubatechcamp_published\\server')
print("Current directory:", os.getcwd())

print("Installing dependencies...")
result = subprocess.run(['npm', 'install'], capture_output=True, text=True)
print("--- STDOUT ---")
print(result.stdout)
print("--- STDERR ---")
print(result.stderr)
print("Dependencies installed.")

# %%
import subprocess
print(subprocess.run(['node', '-v'], capture_output=True, text=True).stdout)
